# %% [markdown]
# # Enter Title

# %% [markdown]
# > ## Problem Statement
#
#
# ???

# %% [markdown]
# > ## Solution
#
# > **Problem**
#
# **???**
#
# > **Input**
#
# 1. **???**
# 2. **???**
#
# > **Output**
#
# 1. **???**
#
# > **Edge Cases**
#
# 1. **???**
# 2. **???**
# 3. **???**
# 4. **???**
# 5. **???**

# %% [markdown]
# ## Test Cases

# %%
tests = {
    'input': {
        'variable_name':'???'
    },
    'output': '???'
}

# %% [markdown]
# ## Solution
# 1. **???**
# 2. **???**
# 3. **???**
# 4. **???**
# 5. **???**

# %% [markdown]
# ## Implementation

# %%
from jovian.pythondsa import evaluate_test_cases
evaluate_test_cases(tests)

# %% [markdown]
# ## Complexity
#
# Time Complexity: `O(N)`
#
# Space Complexity: `O(1)`
